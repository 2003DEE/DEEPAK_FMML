# %% [markdown]
# <a href="https://colab.research.google.com/github/2003DEE/DEEPAK/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.gutenberg.org/files/2348/2348.txt
# Out:
# --2022-08-03 14:26:12--  https://www.gutenberg.org/files/2348/2348.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63373 (62K) [text/plain]
# Saving to: ‘2348.txt’
#
# 2348.txt            100%[===================>]  61.89K  --.-KB/s    in 0.1s
#
# 2022-08-03 14:26:12 (433 KB/s) - ‘2348.txt’ saved [63373/63373]

# %%
file1=open('2348.txt','r')

# %%
file_buffer=file1.read()

# %%
file_list=file_buffer.split()

# %%
import collections as cc

# %%
file_collection=cc.Counter(file_list)

# %%
file_collection
# Out:
# Counter({'The': 44,
#          'Project': 78,
#          'Gutenberg': 21,
#          'EBook': 2,
#          'of': 293,
#          'Disappearance': 4,
#          'Lady': 28,
#          'Frances': 20,
#          'Carfax,': 3,
#          'by': 41,
#          'Arthur': 4,
#          'Conan': 4,
#          'Doyle': 4,
#          'This': 11,
#          'eBook': 5,
#          'is': 127,
#          'for': 68,
#          'the': 547,
#          'use': 8,
#          'anyone': 5,
#          'anywhere': 2,
#          'at': 68,
#          'no': 39,
#          'cost': 2,
#          'and': 242,
#          'with': 112,
#          'almost': 2,
#          'restrictions': 2,
#          'whatsoever.': 2,
#          'You': 21,
#          'may': 31,
#          'copy': 8,
#          'it,': 7,
#          'give': 9,
#          'it': 58,
#          'away': 7,
#          'or': 83,
#          're-use': 2,
#          'under': 11,
#          'terms': 19,
#          'License': 8,
#          'included': 2,
#          'this': 69,
#          'online': 4,
#          'www.gutenberg.org': 2,
#          'Title:': 1,
#          'Carfax': 5,
#          'Author:': 1,
#          'Posting': 1,
#          'Date:': 2,
#          'October': 1,
#          '23,': 1,
#          '2008': 1,
#          '[EBook': 1,
#          '#2348]': 1,
#          'Release': 1,
#          'October,': 1,
#          '2000': 1,
#          '[Last': 1,
#          'updated:': 1,
#          'May': 1,
#          '3,': 1,
#          '2011]': 1,
#          'Language:': 1,
#          'English': 1,
#          'Character': 1,
#          'set': 10,
#          'encoding:': 1,
#          'ASCII': 1,
#          '***': 6,
#          'START': 1,
#          'OF': 12,
#          'THIS': 5,
#          'PROJECT': 4,
#          'GUTENBERG': 3,
#          'EBOOK': 2,
#          'DISAPPEARANCE': 2,
#          'LADY': 2,
#          'CARFAX': 2,
#          'Produced': 2,
#          'David': 2,
#          'Brannan.': 2,
#          'HTML': 2,
#          'version': 3,
#          'Al': 2,
#          'Haines.': 2,
#          'By': 3,
#          'Sir': 1,
#          '"But': 4,
#          'why': 3,
#          'Turkish?"': 1,
#          'asked': 6,
#          'Mr.': 17,
#          'Sherlock': 7,
#          'Holmes,': 10,
#          'gazing': 1,
#          'fixedly': 1,
#          'my': 49,
#          'boots.': 1,
#          'I': 125,
#          'was': 110,
#          'reclining': 1,
#          'in': 184,
#          'a': 226,
#          'cane-backed': 1,
#          'chair': 2,
#          'moment,': 2,
#          'protruded': 1,
#          'feet': 1,
#          'had': 107,
#          'attracted': 1,
#          'his': 55,
#          'ever-active': 1,
#          'attention.': 1,
#          '"English,"': 1,
#          'answered': 4,
#          'some': 26,
#          'surprise.': 1,
#          '"I': 17,
#          'got': 5,
#          'them': 7,
#          "Latimer's,": 1,
#          'Oxford': 1,
#          'Street."': 1,
#          'Holmes': 26,
#          'smiled': 1,
#          'an': 36,
#          'expression': 2,
#          'weary': 1,
#          'patience.': 2,
#          '"The': 7,
#          'bath!"': 1,
#          'he': 52,
#          'said;': 1,
#          '"the': 1,
#          'bath!': 1,
#          'Why': 4,
#          'relaxing': 1,
#          'expensive': 1,
#          'Turkish': 4,
#          'rather': 3,
#          'than': 11,
#          'invigorating': 1,
#          'home-made': 1,
#          'article?"': 1,
#          '"Because': 1,
#          'last': 9,
#          'few': 5,
#          'days': 11,
#          'have': 61,
#          'been': 32,
#          'feeling': 1,
#          'rheumatic': 1,
#          'old.': 1,
#          'A': 15,
#          'bath': 3,
#          'what': 17,
#          'we': 50,
#          'call': 5,
#          'alterative': 1,
#          'medicine--a': 1,
#          'fresh': 5,
#          'starting-point,': 1,
#          'cleanser': 1,
#          'system.': 1,
#          '"By': 2,
#          'way,': 2,
#          'Holmes,"': 3,
#          'added,': 1,
#          'doubt': 2,
#          'connection': 1,
#          'between': 1,
#          'boots': 4,
#          'perfectly': 2,
#          'self-evident': 1,
#          'one': 21,
#          'to': 223,
#          'logical': 2,
#          'mind,': 1,
#          'yet': 6,
#          'should': 20,
#          'be': 49,
#          'obliged': 1,
#          'you': 121,
#          'if': 24,
#          'would': 18,
#          'indicate': 2,
#          'it."': 4,
#          'train': 1,
#          'reasoning': 1,
#          'not': 49,
#          'very': 18,
#          'obscure,': 1,
#          'Watson,"': 6,
#          'said': 31,
#          'mischievous': 1,
#          'twinkle.': 1,
#          '"It': 5,
#          'belongs': 1,
#          'same': 4,
#          'elementary': 1,
#          'class': 2,
#          'deduction': 1,
#          'which': 33,
#          'illustrate': 1,
#          'were': 19,
#          'ask': 4,
#          'who': 29,
#          'shared': 2,
#          'your': 34,
#          'cab': 4,
#          'drive': 2,
#          'morning."': 1,
#          "don't": 1,
#          'admit': 2,
#          'that': 105,
#          'illustration': 1,
#          'explanation,"': 1,
#          'asperity.': 1,
#          '"Bravo,': 1,
#          'Watson!': 1,
#          'dignified': 1,
#          'remonstrance.': 1,
#          'Let': 2,
#          'me': 23,
#          'see,': 2,
#          'points?': 1,
#          'Take': 1,
#          'first--the': 1,
#          'cab.': 1,
#          'observe': 1,
#          'splashes': 1,
#          'on': 35,
#          'left': 22,
#          'sleeve': 1,
#          'shoulder': 1,
#          'coat.': 1,
#          'Had': 3,
#          'sat': 3,
#          'centre': 3,
#          'hansom': 2,
#          'probably': 3,
#          'splashes,': 1,
#          'they': 27,
#          'certainly': 2,
#          'symmetrical.': 1,
#          'Therefore': 2,
#          'clear': 9,
#          'side.': 1,
#          'equally': 1,
#          'companion."': 1,
#          '"That': 6,
#          'evident."': 1,
#          '"Absurdly': 1,
#          'commonplace,': 1,
#          'not?"': 2,
#          'bath?"': 1,
#          '"Equally': 1,
#          'childish.': 1,
#          'are': 35,
#          'habit': 1,
#          'doing': 2,
#          'up': 13,
#          'certain': 3,
#          'way.': 3,
#          'see': 13,
#          'occasion': 1,
#          'fastened': 1,
#          'elaborate': 1,
#          'double': 1,
#          'bow,': 1,
#          'usual': 2,
#          'method': 2,
#          'tying': 1,
#          'them.': 7,
#          'have,': 1,
#          'therefore,': 1,
#          'off.': 1,
#          'Who': 1,
#          'has': 27,
#          'tied': 1,
#          'them?': 1,
#          'bootmaker--or': 1,
#          'boy': 1,
#          'bath.': 2,
#          'It': 22,
#          'unlikely': 1,
#          'bootmaker,': 1,
#          'since': 3,
#          'nearly': 4,
#          'new.': 1,
#          'Well,': 2,
#          'remains?': 1,
#          'Absurd,': 1,
#          'not?': 1,
#          'But,': 1,
#          'all': 35,
#          'that,': 3,
#          'served': 1,
#          'purpose."': 1,
#          '"What': 12,
#          'that?"': 1,
#          '"You': 7,
#          'say': 5,
#          'because': 4,
#          'need': 3,
#          'change.': 2,
#          'suggest': 1,
#          'take': 9,
#          'one.': 3,
#          'How': 1,
#          'Lausanne': 2,
#          'do,': 1,
#          'dear': 5,
#          'Watson--first-class': 1,
#          'tickets': 1,
#          'expenses': 1,
#          'paid': 11,
#          'princely': 1,
#          'scale?"': 1,
#          '"Splendid!': 1,
#          'But': 13,
#          'why?"': 1,
#          'leaned': 1,
#          'back': 6,
#          'armchair': 1,
#          'took': 5,
#          'notebook': 1,
#          'from': 44,
#          'pocket.': 2,
#          '"One': 1,
#          'most': 12,
#          'dangerous': 3,
#          'classes': 1,
#          'world,"': 1,
#          'he,': 2,
#          '"is': 3,
#          'drifting': 1,
#          'friendless': 1,
#          'woman.': 2,
#          'She': 28,
#          'harmless': 2,
#          'often': 4,
#          'useful': 1,
#          'mortals,': 2,
#          'but': 36,
#          'she': 64,
#          'inevitable': 2,
#          'inciter': 1,
#          'crime': 1,
#          'others.': 2,
#          'helpless.': 1,
#          'migratory.': 1,
#          'sufficient': 1,
#          'means': 5,
#          'her': 75,
#          'country': 5,
#          'hotel': 2,
#          'hotel.': 3,
#          'lost,': 1,
#          'as': 63,
#          'not,': 2,
#          'maze': 1,
#          'obscure': 1,
#          'pensions': 1,
#          'boardinghouses.': 1,
#          'stray': 1,
#          'chicken': 1,
#          'world': 3,
#          'foxes.': 1,
#          'When': 5,
#          'gobbled': 1,
#          'hardly': 5,
#          'missed.': 1,
#          'much': 5,
#          'fear': 1,
#          'evil': 1,
#          'come': 6,
#          'Carfax."': 1,
#          'relieved': 1,
#          'sudden': 4,
#          'descent': 1,
#          'general': 3,
#          'particular.': 1,
#          'consulted': 2,
#          'notes.': 1,
#          '"Lady': 1,
#          'Frances,"': 1,
#          'continued,': 1,
#          'sole': 1,
#          'survivor': 1,
#          'direct': 3,
#          'family': 2,
#          'late': 3,
#          'Earl': 1,
#          'Rufton.': 1,
#          'estates': 1,
#          'went,': 2,
#          'remember,': 1,
#          'male': 1,
#          'line.': 1,
#          'limited': 3,
#          'means,': 1,
#          'remarkable': 3,
#          'old': 11,
#          'Spanish': 2,
#          'jewellery': 3,
#          'silver': 1,
#          'curiously': 1,
#          'cut': 1,
#          'diamonds': 1,
#          'fondly': 1,
#          'attached--too': 1,
#          'attached,': 1,
#          'refused': 2,
#          'leave': 6,
#          'banker': 1,
#          'always': 3,
#          'carried': 4,
#          'about': 13,
#          'her.': 9,
#          'pathetic': 1,
#          'figure,': 1,
#          'Frances,': 2,
#          'beautiful': 2,
#          'woman,': 2,
#          'still': 8,
#          'middle': 2,
#          'age,': 1,
#          'yet,': 1,
#          'strange': 4,
#          'change,': 1,
#          'derelict': 1,
#          'only': 16,
#          'twenty': 1,
#          'years': 3,
#          'ago': 2,
#          'goodly': 1,
#          'fleet."': 1,
#          'happened': 3,
#          'her,': 2,
#          'then?"': 1,
#          '"Ah,': 3,
#          'Frances?': 1,
#          'Is': 2,
#          'alive': 1,
#          'dead?': 1,
#          'There': 11,
#          'our': 20,
#          'problem.': 2,
#          'lady': 11,
#          'precise': 1,
#          'habits,': 1,
#          'four': 2,
#          'invariable': 1,
#          'custom': 1,
#          'write': 2,
#          'every': 7,
#          'second': 4,
#          'week': 3,
#          'Miss': 8,
#          'Dobney,': 2,
#          'governess,': 1,
#          'long': 3,
#          'retired': 1,
#          'lives': 2,
#          'Camberwell.': 1,
#          'Dobney': 4,
#          'me.': 8,
#          'Nearly': 2,
#          'five': 1,
#          'weeks': 3,
#          'passed': 9,
#          'without': 16,
#          'word.': 1,
#          'letter': 2,
#          'Hotel': 3,
#          'National': 2,
#          'Lausanne.': 6,
#          'seems': 3,
#          'there': 19,
#          'given': 4,
#          'address.': 3,
#          'anxious,': 1,
#          'exceedingly': 1,
#          'wealthy': 1,
#          'sum': 2,
#          'will': 38,
#          'spared': 1,
#          'can': 25,
#          'matter': 2,
#          'up."': 2,
#          '"Is': 2,
#          'source': 1,
#          'information?': 1,
#          'Surely': 3,
#          'other': 20,
#          'correspondents?"': 1,
#          '"There': 4,
#          'correspondent': 1,
#          'sure': 3,
#          'draw,': 1,
#          'Watson.': 3,
#          'That': 6,
#          'bank.': 1,
#          'Single': 1,
#          'ladies': 2,
#          'must': 17,
#          'live,': 1,
#          'their': 14,
#          'passbooks': 1,
#          'compressed': 1,
#          'diaries.': 1,
#          'banks': 1,
#          "Silvester's.": 1,
#          'glanced': 1,
#          'over': 5,
#          'account.': 1,
#          'check': 6,
#          'bill': 4,
#          'Lausanne,': 2,
#          'large': 3,
#          'cash': 1,
#          'hand.': 1,
#          'Only': 5,
#          'drawn': 2,
#          'since."': 1,
#          '"To': 2,
#          'whom,': 1,
#          'where?"': 1,
#          'Marie': 7,
#          'Devine.': 1,
#          'nothing': 7,
#          'show': 2,
#          'where': 11,
#          'drawn.': 1,
#          'cashed': 1,
#          'Credit': 1,
#          'Lyonnais': 1,
#          'Montpellier': 3,
#          'less': 1,
#          'three': 4,
#          'ago.': 2,
#          'fifty': 2,
#          'pounds."': 1,
#          '"And': 3,
#          'Devine?"': 1,
#          'also': 7,
#          'able': 2,
#          'discover.': 1,
#          'Devine': 1,
#          'maid': 3,
#          'Carfax.': 1,
#          'determined.': 1,
#          'doubt,': 1,
#          'however,': 1,
#          'researches': 1,
#          'soon': 2,
#          '"MY': 1,
#          'researches!"': 1,
#          '"Hence': 1,
#          'health-giving': 1,
#          'expedition': 1,
#          'know': 8,
#          'cannot': 9,
#          'possibly': 1,
#          'London': 4,
#          'while': 1,
#          'Abrahams': 1,
#          'such': 8,
#          'mortal': 1,
#          'terror': 1,
#          'life.': 4,
#          'Besides,': 1,
#          'principles': 1,
#          'best': 3,
#          'country.': 1,
#          'Scotland': 3,
#          'Yard': 1,
#          'feels': 1,
#          'lonely': 3,
#          'me,': 8,
#          'causes': 1,
#          'unhealthy': 1,
#          'excitement': 1,
#          'among': 1,
#          'criminal': 2,
#          'classes.': 1,
#          'Go,': 1,
#          'then,': 2,
#          'Watson,': 11,
#          'humble': 1,
#          'counsel': 1,
#          'ever': 4,
#          'valued': 1,
#          'so': 15,
#          'extravagant': 1,
#          'rate': 1,
#          'two': 6,
#          'pence': 1,
#          'word,': 1,
#          'waits': 1,
#          'disposal': 1,
#          'night': 5,
#          'day': 3,
#          'end': 2,
#          'Continental': 2,
#          'wire."': 1,
#          'Two': 1,
#          'later': 3,
#          'found': 13,
#          'received': 6,
#          'courtesy': 1,
#          'hands': 4,
#          'M.': 2,
#          'Moser,': 1,
#          'well-known': 1,
#          'manager.': 1,
#          'informed': 1,
#          'stayed': 2,
#          'several': 2,
#          'weeks.': 1,
#          'liked': 1,
#          'met': 3,
#          'Her': 4,
#          'age': 1,
#          'more': 10,
#          'forty.': 1,
#          'handsome': 2,
#          'bore': 1,
#          'sign': 2,
#          'having': 2,
#          'youth': 1,
#          'lovely': 1,
#          'Moser': 1,
#          'knew': 1,
#          'any': 41,
#          'valuable': 2,
#          'jewellery,': 1,
#          'remarked': 1,
#          'servants': 1,
#          'heavy': 3,
#          'trunk': 1,
#          "lady's": 4,
#          'bedroom': 1,
#          'scrupulously': 1,
#          'locked.': 1,
#          'Devine,': 1,
#          'maid,': 4,
#          'popular': 1,
#          'mistress.': 2,
#          'actually': 2,
#          'engaged': 2,
#          'head': 4,
#          'waiters': 1,
#          'hotel,': 2,
#          'difficulty': 2,
#          'getting': 4,
#          '11': 1,
#          'Rue': 1,
#          'de': 1,
#          'Trajan,': 1,
#          'Montpellier.': 1,
#          'All': 2,
#          'jotted': 1,
#          'down': 14,
#          'felt': 1,
#          'himself': 1,
#          'could': 22,
#          'adroit': 1,
#          'collecting': 1,
#          'facts.': 1,
#          'corner': 2,
#          'remained': 1,
#          'shadow.': 1,
#          'No': 2,
#          'light': 1,
#          'possessed': 3,
#          'cause': 4,
#          'departure.': 2,
#          'happy': 1,
#          'reason': 5,
#          'believe': 1,
#          'intended': 1,
#          'remain': 4,
#          'season': 1,
#          'luxurious': 1,
#          'rooms': 2,
#          'overlooking': 1,
#          'lake.': 3,
#          'And': 8,
#          'single': 2,
#          "day's": 1,
#          'notice,': 2,
#          'involved': 1,
#          'useless': 1,
#          'payment': 1,
#          "week's": 1,
#          'rent.': 1,
#          'Jules': 5,
#          'Vibart,': 2,
#          'lover': 1,
#          'suggestion': 1,
#          'offer.': 1,
#          'He': 17,
#          'connected': 1,
#          'departure': 2,
#          'visit': 2,
#          'before': 11,
#          'tall,': 2,
#          'dark,': 1,
#          'bearded': 3,
#          'man.': 3,
#          '"Un': 1,
#          'sauvage--un': 1,
#          'veritable': 1,
#          'sauvage!"': 1,
#          'cried': 3,
#          'Vibart.': 1,
#          'man': 11,
#          'somewhere': 2,
#          'town.': 2,
#          'seen': 4,
#          'talking': 2,
#          'earnestly': 1,
#          'Madame': 2,
#          'promenade': 2,
#          'Then': 4,
#          'called.': 1,
#          'him.': 6,
#          'English,': 1,
#          'name': 9,
#          'record.': 1,
#          'place': 8,
#          'immediately': 2,
#          'afterwards.': 1,
#          'and,': 3,
#          'importance,': 1,
#          "Vibart's": 1,
#          'sweetheart,': 1,
#          'thought': 3,
#          'effect.': 2,
#          'thing': 1,
#          'discuss.': 1,
#          'Of': 2,
#          'nothing.': 2,
#          'If': 22,
#          'wished': 1,
#          'know,': 3,
#          'go': 7,
#          'So': 6,
#          'ended': 2,
#          'first': 3,
#          'chapter': 1,
#          'inquiry.': 1,
#          'devoted': 2,
#          'sought': 2,
#          'when': 10,
#          'Concerning': 1,
#          'secrecy,': 1,
#          'confirmed': 2,
#          'idea': 1,
#          'gone': 3,
#          'intention': 1,
#          'throwing': 1,
#          'someone': 3,
#          'off': 7,
#          'track.': 1,
#          'Otherwise': 1,
#          'luggage': 1,
#          'openly': 1,
#          'labelled': 1,
#          'Baden?': 1,
#          'Both': 2,
#          'reached': 4,
#          'Rhenish': 1,
#          'spa': 1,
#          'circuitous': 1,
#          'route.': 1,
#          'gathered': 1,
#          'manager': 4,
#          "Cook's": 1,
#          'local': 1,
#          'office.': 1,
#          'Baden': 4,
#          'after': 9,
#          'dispatching': 1,
#          'account': 1,
#          'proceedings': 1,
#          'receiving': 2,
#          'reply': 2,
#          'telegram': 3,
#          'half-humorous': 1,
#          'commendation.': 1,
#          'At': 3,
#          'track': 2,
#          'difficult': 1,
#          'follow.': 1,
#          'Englischer': 2,
#          'Hof': 1,
#          'fortnight.': 1,
#          'While': 2,
#          'made': 9,
#          'acquaintance': 1,
#          'Dr.': 13,
#          'Shlessinger': 4,
#          'wife,': 4,
#          'missionary': 2,
#          'South': 4,
#          'America.': 2,
#          'Like': 2,
#          'ladies,': 1,
#          'comfort': 1,
#          'occupation': 1,
#          'religion.': 1,
#          "Shlessinger's": 2,
#          'personality,': 1,
#          'whole': 3,
#          'hearted': 1,
#          'devotion,': 1,
#          'fact': 2,
#          'recovering': 1,
#          'disease': 2,
#          'contracted': 1,
#          'exercise': 1,
#          'apostolic': 1,
#          'duties': 1,
#          'affected': 1,
#          'deeply.': 1,
#          'helped': 1,
#          'Mrs.': 3,
#          'nursing': 1,
#          'convalescent': 1,
#          'saint.': 1,
#          'spent': 1,
#          'day,': 2,
#          'described': 2,
#          'upon': 16,
#          'lounge-chair': 1,
#          'veranda,': 1,
#          'attendant': 1,
#          'either': 2,
#          'side': 3,
#          'preparing': 1,
#          'map': 1,
#          'Holy': 2,
#          'Land,': 1,
#          'special': 2,
#          'reference': 1,
#          'kingdom': 1,
#          'Midianites,': 1,
#          'writing': 4,
#          'monograph.': 1,
#          'Finally,': 2,
#          'improved': 1,
#          'health,': 1,
#          'wife': 1,
#          'returned': 1,
#          'London,': 6,
#          'started': 3,
#          'thither': 1,
#          'company.': 1,
#          'just': 7,
#          'before,': 2,
#          'heard': 5,
#          'since.': 1,
#          'As': 2,
#          'Marie,': 2,
#          'beforehand': 1,
#          'floods': 1,
#          'tears,': 1,
#          'informing': 1,
#          'maids': 1,
#          'leaving': 1,
#          'service': 1,
#          'forever.': 2,
#          'party': 2,
#          'way,"': 1,
#          'landlord': 1,
#          'conclusion,': 1,
#          '"you': 1,
#          'friend': 4,
#          'inquiring': 1,
#          'now.': 3,
#          'here': 5,
#          'errand."': 1,
#          '"Did': 2,
#          'name?"': 1,
#          'asked.': 4,
#          '"None;': 1,
#          'Englishman,': 1,
#          'though': 1,
#          'unusual': 1,
#          'type."': 1,
#          '"A': 1,
#          'savage?"': 1,
#          'I,': 1,
#          'linking': 1,
#          'facts': 1,
#          'fashion': 1,
#          'illustrious': 1,
#          'friend.': 1,
#          '"Exactly.': 2,
#          'describes': 1,
#          'him': 12,
#          'well.': 3,
#          'bulky,': 1,
#          'bearded,': 1,
#          'sunburned': 2,
#          'fellow,': 2,
#          'looks': 1,
#          'home': 1,
#          "farmers'": 1,
#          'inn': 1,
#          'fashionable': 1,
#          'hard,': 2,
#          'fierce': 2,
#          'man,': 2,
#          'think,': 3,
#          'whom': 6,
#          'sorry': 1,
#          'offend."': 1,
#          'Already': 2,
#          'mystery': 1,
#          'began': 1,
#          'define': 1,
#          'itself,': 2,
#          'figures': 1,
#          'grow': 1,
#          'clearer': 1,
#          'lifting': 1,
#          'fog.': 1,
#          'Here': 3,
#          'good': 4,
#          'pious': 1,
#          'pursued': 2,
#          'sinister': 1,
#          'unrelenting': 1,
#          'figure.': 2,
#          'feared': 1,
#          'him,': 2,
#          'fled': 1,
#          'followed.': 1,
#          'Sooner': 1,
#          'overtake': 1,
#          'already': 4,
#          'overtaken': 1,
#          'her?': 3,
#          'Was': 1,
#          'THAT': 3,
#          'secret': 1,
#          'continued': 1,
#          'silence?': 1,
#          'Could': 1,
#          'people': 7,
#          'companions': 1,
#          'screen': 1,
#          'violence': 3,
#          'blackmail?': 1,
#          'What': 7,
#          'horrible': 2,
#          'purpose,': 1,
#          'deep': 3,
#          'design,': 1,
#          'lay': 4,
#          'behind': 5,
#          'pursuit?': 1,
#          'problem': 1,
#          'solve.': 1,
#          'To': 7,
#          'wrote': 1,
#          'showing': 1,
#          'how': 8,
#          'rapidly': 1,
#          'surely': 4,
#          'roots': 1,
#          'matter.': 1,
#          'In': 6,
#          'asking': 1,
#          'description': 2,
#          'ear.': 2,
#          "Holmes's": 5,
#          'ideas': 1,
#          'humour': 1,
#          'occasionally': 2,
#          'offensive,': 1,
#          'notice': 4,
#          'ill-timed': 1,
#          'jest--indeed,': 1,
#          'pursuit': 1,
#          'message': 1,
#          'came.': 1,
#          'finding': 2,
#          'ex-servant': 1,
#          'learning': 1,
#          'tell': 4,
#          'creature,': 1,
#          'mistress': 4,
#          'hands,': 1,
#          'own': 9,
#          ...})

# %%
file_dict=dict(file_collection)

# %%
x,y,z=map(int, input().split())
# Out:
# 5 1 3

# %%
file_word_features=[(i,j) for i,j in file_dict.items() if(len(i)>x)and(j>y)and(j<z)]

# %%
file_word_features
# Out:
# [('anywhere', 2),
#  ('almost', 2),
#  ('restrictions', 2),
#  ('whatsoever.', 2),
#  ('re-use', 2),
#  ('included', 2),
#  ('www.gutenberg.org', 2),
#  ('DISAPPEARANCE', 2),
#  ('CARFAX', 2),
#  ('Produced', 2),
#  ('Brannan.', 2),
#  ('Haines.', 2),
#  ('moment,', 2),
#  ('expression', 2),
#  ('patience.', 2),
#  ('perfectly', 2),
#  ('logical', 2),
#  ('indicate', 2),
#  ('shared', 2),
#  ('hansom', 2),
#  ('certainly', 2),
#  ('Therefore', 2),
#  ('method', 2),
#  ('change.', 2),
#  ('Lausanne', 2),
#  ('pocket.', 2),
#  ('woman.', 2),
#  ('harmless', 2),
#  ('mortals,', 2),
#  ('inevitable', 2),
#  ('others.', 2),
#  ('consulted', 2),
#  ('family', 2),
#  ('Spanish', 2),
#  ('refused', 2),
#  ('Frances,', 2),
#  ('beautiful', 2),
#  ('woman,', 2),
#  ('middle', 2),
#  ('problem.', 2),
#  ('Dobney,', 2),
#  ('Nearly', 2),
#  ('letter', 2),
#  ('National', 2),
#  ('matter', 2),
#  ('ladies', 2),
#  ('Lausanne,', 2),
#  ('criminal', 2),
#  ('Continental', 2),
#  ('stayed', 2),
#  ('several', 2),
#  ('handsome', 2),
#  ('having', 2),
#  ('valuable', 2),
#  ('mistress.', 2),
#  ('actually', 2),
#  ('engaged', 2),
#  ('hotel,', 2),
#  ('difficulty', 2),
#  ('corner', 2),
#  ('departure.', 2),
#  ('single', 2),
#  ('notice,', 2),
#  ('Vibart,', 2),
#  ('departure', 2),
#  ('somewhere', 2),
#  ('talking', 2),
#  ('Madame', 2),
#  ('promenade', 2),
#  ('immediately', 2),
#  ('effect.', 2),
#  ('nothing.', 2),
#  ('devoted', 2),
#  ('sought', 2),
#  ('confirmed', 2),
#  ('receiving', 2),
#  ('Englischer', 2),
#  ('missionary', 2),
#  ('America.', 2),
#  ("Shlessinger's", 2),
#  ('disease', 2),
#  ('described', 2),
#  ('either', 2),
#  ('special', 2),
#  ('Finally,', 2),
#  ('before,', 2),
#  ('Marie,', 2),
#  ('forever.', 2),
#  ('"Exactly.', 2),
#  ('sunburned', 2),
#  ('fellow,', 2),
#  ('fierce', 2),
#  ('Already', 2),
#  ('itself,', 2),
#  ('pursued', 2),
#  ('figure.', 2),
#  ('horrible', 2),
#  ('description', 2),
#  ('occasionally', 2),
#  ('finding', 2),
#  ('Baden,', 2),
#  ('suspicions', 2),
#  ('parting', 2),
#  ('stranger', 2),
#  ('driven', 2),
#  ('accepted', 2),
#  ('London.', 2),
#  ('nervous', 2),
#  ('suddenly', 2),
#  ('sprang', 2),
#  ('surprise', 2),
#  ('cried.', 2),
#  ('Through', 2),
#  ('sitting-room', 2),
#  ('slowly', 2),
#  ('street', 2),
#  ('staring', 2),
#  ('myself,', 2),
#  ('"Where', 2),
#  ('stared', 2),
#  ('darted', 2),
#  ('cabaret', 2),
#  ('attack.', 2),
#  ('entered', 2),
#  ('explanation', 2),
#  ('appearance', 2),
#  ('obvious', 2),
#  ('appearance.', 2),
#  ('effect', 2),
#  ('discover', 2),
#  ('beyond', 2),
#  ('remember', 2),
#  ('others', 2),
#  ('myself', 2),
#  ('address,', 2),
#  ('Langham', 2),
#  ('to-morrow."', 2),
#  ('answered.', 2),
#  ('clerical', 2),
#  ('answer', 2),
#  ('Shlessinger,', 2),
#  ('undoubtedly', 2),
#  ('former', 2),
#  ('evening', 2),
#  ('police', 2),
#  ('mystery.', 2),
#  ('suddenly,', 2),
#  ('pendant', 2),
#  ('Westminster', 2),
#  ('clean-shaven', 2),
#  ('address', 2),
#  ('constant', 2),
#  ('prepare', 2),
#  ('"These', 2),
#  ('questions', 2),
#  ('consent."', 2),
#  ('Kennington', 2),
#  ('longer,', 2),
#  ("ordinary.'", 2),
#  ('doorway.', 2),
#  ('house."', 2),
#  ('windows', 2),
#  ('standing', 2),
#  ('closed', 2),
#  ('remembered', 2),
#  ('murder', 2),
#  ('Green.', 2),
#  ('hurried', 2),
#  ('desperate', 2),
#  ('Square.', 2),
#  ('reconstruct', 2),
#  ('inside', 2),
#  ('course,', 2),
#  ('medical', 2),
#  ('certificate', 2),
#  ('buried', 2),
#  ('approach', 2),
#  ('Watson?', 2),
#  ("o'clock", 2),
#  ('everything', 2),
#  ('enough.', 2),
#  ('together,', 2),
#  ('here,"', 2),
#  ('firmly.', 2),
#  ('showed', 2),
#  ('farther', 2),
#  ('Holmes."', 2),
#  ('coolly.', 2),
#  ('business', 2),
#  ('house?"', 2),
#  ('hundred', 2),
#  ('couple', 2),
#  ('attached', 2),
#  ('warrant?"', 2),
#  ('comes."', 2),
#  ('common', 2),
#  ('passage,', 2),
#  ('entered.', 2),
#  ('raised', 2),
#  ('lights', 2),
#  ('Workhouse', 2),
#  ("that's", 2),
#  ('friend,', 2),
#  ('sergeant,', 2),
#  ('Sergeant,', 2),
#  ('warrant', 2),
#  ('charitable', 2),
#  ('obtained', 2),
#  ('further', 2),
#  ('quick!', 2),
#  ('never,', 2),
#  ('late!"', 2),
#  ('minutes', 2),
#  ('shouted', 2),
#  ('giving!', 2),
#  ('effort', 2),
#  ('actual', 2),
#  ('chloroform,', 2),
#  ('modified', 2),
#  ('credit', 2),
#  ('sentence,', 2),
#  ('easily', 2),
#  ('reported', 2),
#  ('formats', 2),
#  ('paying', 2),
#  ('license,', 2),
#  ('copying', 2),
#  ('protect', 2),
#  ('concept', 2),
#  ('registered', 2),
#  ('eBooks,', 2),
#  ('printed', 2),
#  ('eBooks.', 2),
#  ('LICENSE', 2),
#  ('promoting', 2),
#  ('intellectual', 2),
#  ('property', 2),
#  ('destroy', 2),
#  ('obtaining', 2),
#  ('1.E.8.', 2),
#  ('States,', 2),
#  ('copying,', 2),
#  ('displaying', 2),
#  ('references', 2),
#  ('keeping', 2),
#  ('displaying,', 2),
#  ('concerning', 2),
#  ('1.E.1.', 2),
#  ('active', 2),
#  ('immediate', 2),
#  ('prominently', 2),
#  ('copied', 2),
#  ('contain', 2),
#  ('requirements', 2),
#  ('License.', 2),
#  ('marked', 2),
#  ('"Plain', 2),
#  ('Vanilla', 2),
#  ('ASCII"', 2),
#  ('specified', 2),
#  ('Royalty', 2),
#  ('receipt', 2),
#  ('accordance', 2),
#  ('defect', 2),
#  ('Michael', 2),
#  ('employees', 2),
#  ('considerable', 2),
#  ('defective', 2),
#  ('medium,', 2),
#  ('computer', 2),
#  ('equipment.', 2),
#  ('DAMAGES', 2),
#  ('Except', 2),
#  ('expenses,', 2),
#  ('BREACH', 2),
#  ('refund.', 2),
#  ('WARRANTIES', 2),
#  ('disclaimer', 2),
#  ('permitted', 2),
#  ('readable', 2),
#  ('widest', 2),
#  ('created', 2),
#  ('501(c)(3)', 2),
#  ('exempt', 2),
#  ('federal', 2),
#  ('information', 2),
#  ('https://pglaf.org', 2),
#  ('Donations', 2),
#  ('solicit', 2)]

# %%
file_feature_list=str(file_word_features)

# %%
file2=open('feature_list.txt','w')

# %%
file2.write(file_feature_list)
# Out:
# 4867

# %%
file1.close()

# %%
file2.close()
