# %% [markdown]
# <a href="https://colab.research.google.com/github/2003DEE/DEEPAK/blob/main/Lab%208%20module%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 16:06:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   212MB/s    in 0.3s
#
# 2023-05-27 16:06:45 (212 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['navy', 'green', 'crimson']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5578    1303.3257v3  In a broad range of classification and decisio...  stat
# 10559   1303.2663v2  Spectral clustering is widely used to partitio...    cs
# 6337   1611.04920v2  Gaussian graphical models (GGMs) are widely us...  stat
# 35779   1204.5859v3  While looking for abductive explanations of a ...    cs
# 22995  1801.05772v1  We formulate a supervised learning problem, re...  stat
# ...             ...                                                ...   ...
# 5663   1604.04434v1  As an automatic method of determining model co...    cs
# 9615    1208.2651v1  In a context where most published articles are...  stat
# 22568  1701.02071v1  Gaussian graphical model is a graphical repres...  stat
# 40951   1310.0890v1  To achieve effective and efficient detection o...    cs
# 22169  1506.04138v1  The latent block model (LBM) is a flexible pro...  stat
#
#                                                    title  year  \
# 5578   Ranking and combining multiple predictors with...  2013
# 10559        Spectral Clustering with Epidemic Diffusion  2013
# 6337   Unsupervised Learning with Truncated Gaussian ...  2016
# 35779  On the Complexity of Finding Second-Best Abduc...  2012
# 22995  Ranking Data with Continuous Labels through Or...  2018
# ...                                                  ...   ...
# 5663   Bayesian linear regression with Student-t assu...  2016
# 9615   A Plea for Neutral Comparison Studies in Compu...  2012
# 22568  Optimal statistical decision for Gaussian grap...  2017
# 40951  Multiple Kernel Learning in the Primal for Mul...  2013
# 22169  Exact ICL maximization in a non-stationary tim...  2015
#
#                                                 keywords
# 5578   [classification, predictions, classifiers, rel...
# 10559  [clustering, partition, communities, clusterin...
# 6337   [graphical, statistical, inference, ubiquitous...
# 35779  [abductive, explanations, manifestations, solu...
# 22995  [formulate, supervised, continuous, continuous...
# ...                                                  ...
# 5663   [automatic, determining, complexity, regressio...
# 9615   [published, development, comparison, generally...
# 22568  [graphical, graphical, representation, depende...
# 40951  [effective, efficient, detection, alzheimers, ...
# 22169  [probabilistic, interactions, bipartite, inter...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5578     [classification, predictions, classifiers, rel...
# 10559    [clustering, partition, communities, clusterin...
# 6337     [graphical, statistical, inference, ubiquitous...
# 35779    [abductive, explanations, manifestations, solu...
# 22995    [formulate, supervised, continuous, continuous...
#                                ...
# 17456    [attention, mechanism, including, attention, a...
# 22212    [calibration, adjusting, computational, framew...
# 32898    [investigate, attention, information, contrast...
# 21669    [introduce, supersparse, classification, theor...
# 27617    [automatic, segmentation, connectomics, correc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8785 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ddb39892-aa84-4005-91ab-bd893a605673" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddb39892-aa84-4005-91ab-bd893a605673")) {                    Plotly.newPlot(                        "ddb39892-aa84-4005-91ab-bd893a605673",                        [{"x":["correspond","conditional","available","prediction","eigenvector","predictors","independence","covariance","unlabeled","classifiers","supervised","questions","different","furthermore","combining","estimating","classification","accuracies","predictions","reliability","approximation","simulated","classifier","malicious","construct","typically","proportional","likelihood","estimator","clustering","partition","effectively","replicator","neighbors","synthetic","symmetric","associated","centralities","transitions","demonstrate","equivalent","partitioning","structures","eigenvalues","reweighted","normalized","partitions","properties","techniques","traditional","communities","diffusion","simultaneously","eigenvectors","performance","laplacian","preference","structure","connecting","describing","community","abilities","efficient","practical","introduce","variables","nonlinearity","graphical","rectifier","restriction","statistical","bipartite","specifically","contrastive","accounting","inference","truncated","superiority","rectified","constructs","divergence","extensive","competing","experimental","efficiently","ubiquitous","meanwhile","constructions","unsupervised","assumption","connection","distribution","appealing","distributions","approximations","definitions","solutions","explanations","computational","complexity","orderings","manifestations","abductive","described","highlight","dedicated","continuous","conditions","guarantees","numerical","empirical","theoretical","regression","recursive","generalizes","optimizers","preliminary","functions","candidates","probability","formulate","maximization","experiments","functional","naturally","difference","observable","criterion","piecewise","appropriate","producing","algorithm","optimization","observations","appearing","implications","important","interactions","addressing","identifying","addressed","challenges","understanding","particularly","represent","detection","affordances","behaviour","annotation","relationships","relationship","mechanism","overlooked","explanation","evidential","strategies","probabilistically","generating","inferences","intuitive","practitioners","particular","determining","generated","orientation","independent","relations","interested","dictionaries","containing","sentiments","portability","sentiment","respectively","precision","sentiwordnet","approximately","hierarchical","advantages","correlated","coordinate","approximate","algorithms","conditionally","posterior","application","probabilistic","variational","nonconjugate","conjugate","biomedical","considered","information","primitive","applications","informatics","components","comprehensive","investigate","operators"],"y":[29,97,280,216,3,10,32,21,41,111,171,68,752,161,112,61,509,15,89,23,103,50,133,6,104,119,10,65,24,146,20,101,4,22,125,27,109,2,15,566,60,16,136,4,5,19,11,220,383,178,18,21,139,4,874,24,29,342,13,30,74,11,407,133,340,128,2,49,1,14,146,6,174,8,6,212,4,37,2,15,19,174,22,378,158,10,19,6,144,58,44,212,14,104,20,23,154,17,291,233,3,2,9,66,33,21,96,127,66,78,152,137,96,35,36,6,53,212,21,182,60,28,604,48,66,61,24,35,8,74,27,812,301,78,8,31,352,83,27,71,35,127,171,70,126,318,3,37,62,73,72,108,5,17,7,95,5,98,11,27,11,252,41,163,37,130,95,22,17,75,5,3,43,92,81,2,32,98,93,28,26,117,600,1,32,208,166,53,0,12,13,147,705,6,419,1,113,63,145,45],"type":"bar"},{"x":["correspond","conditional","available","prediction","eigenvector","predictors","independence","covariance"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Compact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style='background-color:rgba(0, 255, 0, 0.4154727793696275);'>Representations</span> <span style=''>for</span> <span style=''>Audio</span> <span style=''>Events</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>Regressor</span> <span style=''>Banks</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.6774193548387097);'>descriptor</span> <span style=''>for</span> <span style=''>audio</span> <span style=''>signals</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>for</span> <span style=''>event</span> <span style='background-color:rgba(0, 255, 0, 0.4022556390977444);'>representation</span> <span style=''>The</span> <span style=''>entries</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6774193548387097);'>descriptor</span> <span style=''>are</span> <span style=''>produced</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.30120481927710846);'>evaluating</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regressors</span> <span style=''>on</span> <span style=''>the</span> <span style=''>input</span> <span style=''>signal</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regressors</span> <span style=''>are</span> <span style=''>class</span> <span style=''>specific</span> <span style=''>and</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>the</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.5826086956521739);'>regression</span> <span style=''>forests</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>Given</span> <span style=''>an</span> <span style=''>input</span> <span style=''>signal</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>regressor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>the</span> <span style=''>onset</span> <span style=''>and</span> <span style=''>offset</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>positions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>event</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>scores</span> <span style=''>output</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>regressor</span> <span style=''>are</span> <span style=''>then</span> <span style=''>used</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>how</span> <span style=''>the</span> <span style=''>target</span> <span style=''>event</span> <span style=''>aligns</span> <span style=''>with</span> <span style=''>the</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>category</span> <span style=''>Our</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.6774193548387097);'>descriptor</span> <span style=''>has</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bennett</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inequality</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Missing</span> <span style=''>Mass</span> <br/><br/><span style=''>Novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concentration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>for</span> <span style=''>the</span> <span style=''>missing</span> <span style=''>mass</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>mass</span> <span style=''>of</span> <span style=''>the</span> <span style=''>outcomes</span> <span style=''>not</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>We</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviation</span> <span style=''>bounds</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponents</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviation</span> <span style=''>size</span> <span style=''>for</span> <span style=''>missing</span> <span style=''>mass</span> <span style=''>and</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>Berend</span> <span style=''>and</span> <span style=''>Kontorovich</span> <span style=''>(2013)</span> <span style=''>and</span> <span style=''>Yari</span> <span style=''>Saeed</span> <span style=''>Khanloo</span> <span style=''>and</span> <span style=''>Haffari</span> <span style=''>(2015)</span> <span style=''>for</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviations</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>case</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>theory</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fourier</span> <span style=''>PCA</span> <span style=''>and</span> <span style=''>Robust</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>Fourier</span> <span style=''>PCA</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.425);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>obtained</span> <span style=''>from</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivatives</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>logarithm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fourier</span> <span style='background-color:rgba(0, 255, 0, 0.43181818181818177);'>transform</span> <span style=''>of</span> <span style=''>a</span> <span style=''>distributionWe</span> <span style=''>make</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>a</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>method</span> <span style=''>for</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>tensors</span> <span style=''>sharing</span> <span style=''>the</span> <span style=''>same</span> <span style=''>vectors</span> <span style=''>in</span> <span style=''>rank</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompositions</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>provably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>underdetermined</span> <span style=''>ICA</span> <span style=''>ie</span> <span style=''>learning</span> <span style=''>an</span> <span style=''>n</span> <span style=''>times</span> <span style=''>m</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.33898305084745767);'>observations</span> <span style=''>yAx</span> <span style=''>where</span> <span style=''>x</span> <span style=''>is</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>product</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style='background-color:rgba(255, 0, 0, 0.37160120845921446);'>distributions</span> <span style=''>m</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrarily</span> <span style=''>higher</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37623762376237624);'>dimension</span> <span style=''>n</span> <span style=''>and</span> <span style=''>the</span> <span style=''>column ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style=''>Missing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Corrupted</span> <span style=''>Data</span> <br/><br/><span style=''>Given</span> <span style=''>full</span> <span style=''>or</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>points</span> <span style=''>that</span> <span style=''>lie</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>union</span> <span style=''>of</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>refers</span> <span style=''>to</span> <span style=''>the</span> <span style=''>process</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>the</span> <span style=''>points</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>their</span> <span style=''>subspace</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>One</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>sparse</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>(SSC)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>each</span> <span style=''>sample</span> <span style=''>as</span> <span style=''>a</span> <span style=''>weighted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>other</span> <span style=''>samples</span> <span style=''>with</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>minimal</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>then</span> <span style=''>uses</span> <span style=''>those</span> <span style=''>learned</span> <span style=''>weights</span> <span style=''>to</span> <span style=''>cluster</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>SSC</span> <span style=''>is</span> <span style=''>stable</span> <span style=''>in</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>each</span> <span style=''>sample</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contaminated</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>small</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>However</span> <span style=''>when</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>additive</span> <span style=''>noise</span> <span style=''>or</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style=''>number</span> <span style=''>of</span> <span style=''>entries</span> <span style=''>are</span> <span style=''>missing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08582621082621082)
# 	segmentation (0.06588319088319089)
# 	challenging (0.1047008547008547)
# 	representation (0.13283475783475784)
# 	information (0.25106837606837606)
# 	knowledge (0.1267806267806268)
# 	detection (0.11324786324786325)
# 	different (0.2678062678062678)
# 	recognition (0.12535612535612536)
# 	convolutional (0.12784900284900286)
#
# Some Statistics words are:
# 	variational (0.10190763052208836)
# 	estimation (0.16666666666666666)
# 	statistical (0.14809236947791166)
# 	variables (0.1536144578313253)
# 	theoretical (0.16415662650602408)
# 	algorithm (0.4046184738955823)
# 	distribution (0.1922690763052209)
# 	inference (0.19879518072289157)
# 	dimensional (0.18775100401606426)
# 	regression (0.1827309236947791)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6dbcb87d-c289-413b-8825-edc82f8c845f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dbcb87d-c289-413b-8825-edc82f8c845f")) {                    Plotly.newPlot(                        "6dbcb87d-c289-413b-8825-edc82f8c845f",                        [{"x":["correspond","conditional","available","prediction","eigenvector","predictors","independence","covariance","unlabeled","classifiers","supervised","questions","different","furthermore","combining","estimating","classification","accuracies","predictions","reliability","approximation","simulated","classifier","malicious","construct","typically","proportional","likelihood","estimator","clustering","partition","effectively","replicator","neighbors","synthetic","symmetric","associated","centralities","transitions","demonstrate","equivalent","partitioning","structures","eigenvalues","reweighted","normalized","partitions","properties","techniques","traditional","communities","diffusion","simultaneously","eigenvectors","performance","laplacian","preference","structure","connecting","describing","community","abilities","efficient","practical","introduce","variables","nonlinearity","graphical","rectifier","restriction","statistical","bipartite","specifically","contrastive","accounting","inference","truncated","superiority","rectified","constructs","divergence","extensive","competing","experimental","efficiently","ubiquitous","meanwhile","constructions","unsupervised","assumption","connection","distribution","appealing","distributions","approximations","definitions","solutions","explanations","computational","complexity","orderings","manifestations","abductive","described","highlight","dedicated","continuous","conditions","guarantees","numerical","empirical","theoretical","regression","recursive","generalizes","optimizers","preliminary","functions","candidates","probability","formulate","maximization","experiments","functional","naturally","difference","observable","criterion","piecewise","appropriate","producing","algorithm","optimization","observations","appearing","implications","important","interactions","addressing","identifying","addressed","challenges","understanding","particularly","represent","detection","affordances","behaviour","annotation","relationships","relationship","mechanism","overlooked","explanation","evidential","strategies","probabilistically","generating","inferences","intuitive","practitioners","particular","determining","generated","orientation","independent","relations","interested","dictionaries","containing","sentiments","portability","sentiment","respectively","precision","sentiwordnet","approximately","hierarchical","advantages","correlated","coordinate","approximate","algorithms","conditionally","posterior","application","probabilistic","variational","nonconjugate","conjugate","biomedical","considered","information","primitive","applications","informatics","components","comprehensive","investigate","operators","algorithmic","measuring","complexities","operations","representations","constraints","collectively","contextual","engineering","ontologies","factorizes","alternative","heterogeneous","associations","factorization","individual","approaches","expressed","penalized","integration","perspectives","favorably","including","databases","advantage","background","increasing","recommended","identification","essential","developed","compressing","according","transform","significant","employing","biometric","improvement","compression","fingerprints","performances","standards","arbitrary","automatic","sufficient","ineffective","geometrical","exponential","identified","fingerprint","computing","orientations","compressed","rectangle","assignment","selection","existence","clas ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonconjugate
# 	asymptotics
# 	advocates
# 	crossings
# 	unnecessarily
# 	presupposes
# 	nonparanormal
# 	obscuring
# 	specialist
# 	invariably
# 	confounders
# 	deteriorates
# 	submatrix
# 	aggressive
# 	faithfully
# 	validator
# 	isomorphism
# 	oblivious
# 	composers
# 	inexactly
# Some words which never appear in Statistics papers:
# 	replicator
# 	orderings
# 	manifestations
# 	abductive
# 	affordances
# 	evidential
# 	portability
# 	sentiwordnet
# 	rectangle
# 	specialization
# 	symbiotic
# 	articulated
# 	polysemous
# 	discourse
# 	impoverished
# 	ambitious
# 	collector
# 	librispeech
# 	attempted
# 	executing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.064194882794546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
