# %% [markdown]
# <a href="https://colab.research.google.com/github/2003DEE/DEEPAK/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix,plot_confusion_matrix
import numpy as np
import pandas 
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
def pred(X,y,features,classes,max_depth,criterion="gini",min_samples_split=2,min_samples_leaf=1):
  TEE=tree.DecisionTreeClassifier(max_depth=max_depth,\
                                  criterion=criterion,\
                                  min_samples_split=min_samples_split,\
                                  min_samples_leaf=min_samples_leaf,\
                                  splitter="best",\
                                  random_state=0,\
                                  )
  X_train,Y_train=X
  X_test,Y_test=y
  TEE=TEE.fit(X_train,Y_train)
  Y_prd=TEE.predict(Y_test)
  print(accuracy_score(Y_prd,Y_test))




def give_ex(n):
  pred((X_train,Y_train),(X_test,Y_test),features=iris["feature_names"],classes=iris["target_names"],max_depth=n)

# %%
iris=load_iris()
X,Y=iris.data,iris.target
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0)
iris_data=pandas.DataFrame(\
                data=np.hstack((X,Y.reshape(Y.shape[0],1),[[iris["target_names"][int(classIdx)]] for classIdx in y])),\
                columns=["sepal_length","sepal_width","petal_length","petal_width","class","className"])
                       
iris_data.sample(n=10,random_state=1)
# Out:
#     sepal_length sepal_width petal_length petal_width class   className
# 14           5.8         4.0          1.2         0.2     0      setosa
# 98           5.1         2.5          3.0         1.1     1  versicolor
# 75           6.6         3.0          4.4         1.4     1  versicolor
# 16           5.4         3.9          1.3         0.4     0      setosa
# 131          7.9         3.8          6.4         2.0     2   virginica
# 56           6.3         3.3          4.7         1.6     1  versicolor
# 141          6.9         3.1          5.1         2.3     2   virginica
# 44           5.1         3.8          1.9         0.4     0      setosa
# 29           4.7         3.2          1.6         0.2     0      setosa
# 120          6.9         3.2          5.7         2.3     2   virginica

# %%
give_ex(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-64b00563593f> in <module>
# ----> 1 give_ex(5)
#
# <ipython-input-38-dfd85ec30486> in give_ex(n)
#      17
#      18 def give_ex(n):
# ---> 19   pred((X_train,Y_train),(X_test,Y_test),features=iris["feature_names"],classes=iris["target_names"],max_depth=n)
#
# <ipython-input-38-dfd85ec30486> in pred(X, y, features, classes, max_depth, criterion, min_samples_split, min_samples_leaf)
#      10   X_test,Y_test=y
#      11   TEE=TEE.fit(X_train,Y_train)
# ---> 12   Y_prd=TEE.predict(Y_test)
#      13   print(accuracy_score(Y_prd,Y_test))
#      14
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
# ...
