# %% [markdown]
# <a href="https://colab.research.google.com/github/2003DEE/DEEPAK/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets

# %%
data=pd.read_csv("/content/Employee_monthly_salary.csv")
data.head()
# Out:
#    EmpID            Name Gender Date_of_Birth  Age   Join_Date  \
# 0  19575    Keven Norman      M    03-09-1994   25  02-12-2019
# 1  19944  Kristin Werner      F    23-06-1994   26  13-01-2020
# 2  20055    Avery Barber      M    27-02-1996   24  14-11-2019
# 3  20058    Boris Gibson      M    29-09-1993   26  13-01-2020
# 4  20332       Leif Mack      M    01-05-1991   29  04-06-2018
#
#    Tenure_in_org_in_months   GROSS  Net_Pay  Deduction  Deduction_percentage  \
# 0                        7   74922    71494       3428                  4.58
# 1                        6   44375    39971       4404                  9.92
# 2                        8   82263    77705       4558                  5.54
# 3                        6   44375    40164       4211                  9.49
# 4                       25  235405   143963      91442                 38.84
#
#                                Designation                     Department
# ...

# %%
data.shape
# Out:
# (1802, 13)

# %%
data.replace("?", np.nan, inplace = True)
data = data.dropna()
print(len(data))
# Out:
# 1802

# %%
X = data.drop("Age", axis = 1)
y = pd.to_numeric(data["Age"])

# %%
Y=data.drop("Net_Pay",axis=1)
x=pd.to_numeric(data["Net_Pay"])

# %%
plt.figure(figsize = (24, 7))
plt.scatter(X["Net_Pay"], y)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs salary')
plt.show()

# %%
from sklearn.manifold import Isomap

# %%
n_points=len(data)
print(n_points)
# Out:
# 1802

# %%
fig = plt.figure(figsize=(15, 12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data, c=color, cmap=plt.cm.Spectral)
ax.view_init(4, -72)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-80916da74631> in <module>
#       1 fig = plt.figure(figsize=(15, 12))
#       2 ax = fig.add_subplot(111, projection='3d')
# ----> 3 ax.scatter(data, c=color, cmap=plt.cm.Spectral)
#       4 ax.view_init(4, -72)
#
# TypeError: scatter() missing 1 required positional argument: 'ys'
